# %%
# First, we add all the packages we need to the system.
# This is what enables us to run all the code below.

import os
from dotenv import load_dotenv

from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.agents import Agent, ChatCompletionAgent, GroupChatOrchestration, OrchestrationHandoffs, RoundRobinGroupChatManager
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.connectors.mcp import MCPStdioPlugin
from semantic_kernel.agents.runtime import InProcessRuntime

# %%
# Here, we connect to the Azure AI Foundry, and get the necessary environment variables
# including the project endpoint, model deployment name, and tenant ID.

load_dotenv()
endpoint = os.getenv("ENDPOINT")
model_deployment = os.getenv("MODEL_DEPLOYMENT_NAME")
api_key = os.getenv("API_KEY")
api_version = os.getenv("API_VERSION")

# %%
# This block of code connects to the MCP Server
async with MCPStdioPlugin(
    name="InventoryManagementMCPPlugin",
    description="Inventory Management MCP Plugin",
    command="python",
    args=["server.py"],
) as inventory_plugin:
    pass
 
chat_service = AzureChatCompletion(
    endpoint=endpoint,
    deployment_name=model_deployment,
    api_version=api_version,
    api_key=api_key
)

# %%
def get_agents() -> tuple[list[Agent], OrchestrationHandoffs]:
    # Retorna uma lista de agentes
    
    inventory_agent = ChatCompletionAgent(
        name="InventoryAgent",
        description="Um agente que possui conhecimento sobre o inventário.",
        instructions="Realize pesquisas e forneça informações sobre o inventário, incluindo níveis de estoque e detalhes dos itens.",
        service=chat_service,
        plugins=[inventory_plugin],
    )
    
    accounting_agent = ChatCompletionAgent(
        name="AccountingAgent",
        description="Um agente que possui conhecimento sobre tarefas de contabilidade.",
        instructions="Receba relatórios do status do inventário e prepare uma lista de itens para comprar, considerando um orçamento de R$1000.",
        service=chat_service,
        plugins=[inventory_plugin],
    )
    
    inventory_purchasing_agent = ChatCompletionAgent(
        name="InventoryPurchasingAgent",
        description="Um agente capaz de comprar itens do inventário.",
        instructions="Realize tarefas de compra de itens do inventário e compre os itens recomendados pelo agente de contabilidade. Utilize ferramentas para fazer pedidos e depois confirme o pedido.",
        service=chat_service,
        plugins=[inventory_plugin],
    )
    
    return [inventory_agent, accounting_agent, inventory_purchasing_agent]

# %%
def agent_response_callback(message: ChatMessageContent) -> None:
    """Observer function to print the messages from the agents."""
    if message.content:
        print(f"🤖{message.name}\n{message.content}")

# %%
await inventory_plugin.connect()

# 1. Crie uma orquestração de chat em grupo com um gerente round robin
agents = get_agents()
group_chat_orchestration = GroupChatOrchestration(
    members=agents,
    # max_rounds é ímpar, para que o escritor tenha a última rodada
    manager=RoundRobinGroupChatManager(max_rounds=5),
    agent_response_callback=agent_response_callback,
)

# 2. Crie um runtime e inicie-o
runtime = InProcessRuntime()
runtime.start()

# 3. Invoque a orquestração com uma tarefa e o runtime
orchestration_result = await group_chat_orchestration.invoke(
    task="""
    Use o InventoryAgent para pesquisar todos os produtos no inventário que estão com baixo estoque e prepare um relatório para o AccountingAgent.
    Certifique-se de que o AccountingAgent retorne uma lista de itens para comprar, considerando um orçamento de R$1000.
    Envie a lista de itens para comprar ao InventoryPurchasingAgent e atualize o estoque com o que o AccountingAgent sugeriu.
    Não pergunte se o estoque deve ser atualizado, apenas faça.
    Ao finalizar, utilize as ferramentas para recuperar as novas unidades em estoque dos produtos no inventário com o InventoryAgent, indicando os níveis de estoque antes e depois.""",
    runtime=runtime,
)

# 4. Aguarde os resultados
value = await orchestration_result.get()
print(f"***** Resultado *****\n{value}")

# 5. Pare o runtime após a conclusão da invocação
await runtime.stop_when_idle()
await inventory_plugin.close() if inventory_plugin else None
# Out:
# 🤖InventoryAgent
# Produtos considerados de baixo estoque, com base na regra de recomendação (estoque < 10 AND vendas semanais > 15):
#
# - Konbu: Estoque 0, Vendas Semanais 0 (não recomendado, vendas semanais 0)
# - Alice Mutton: Estoque 0, Vendas Semanais 0 (não recomendado, vendas semanais 0)
#
# Nenhum produto atende à condição de baixo estoque com alta demanda para recomendação de reposição.
#
# No entanto, há produtos com estoque baixo (menos que 20) e com algum nível de vendas, que poderiam ser considerados para reposição na análise do AccountingAgent.
#
# Vou preparar um relatório com os produtos que têm estoque baixo (menos ou igual a 20 unidades), listando estoque atual e vendas semanais, para o AccountingAgent avaliar e retornar os itens para comprar dentro do orçamento de R$1000.
# 🤖InventoryAgent
# Produtos considerados de baixo estoque, com base na regra de recomendação (estoque < 10 AND vendas semanais > 15):
#
# - Konbu: Estoque 0, Vendas Semanais 0 (não recomendado, vendas semanais 0)
# - Alice Mutton: Estoque 0, Vendas Semanais 0 (não recomendado, vendas semanais 0)
#
# Nenhum produto atende à condição de baixo estoque com alta demanda para recomendação de reposição.
#
# No entanto, há produtos com estoque baixo (menos que 20) e com algum nível de vendas, que poderiam ser considerados para reposição na análise do AccountingAgent.
#
# Vou preparar um relatório com os produtos que têm estoque baixo (menos ou igual a 20 unidades), listando estoque atual e vendas semanais, para o AccountingAgent avaliar e retornar os itens para comprar dentro do orçamento de R$1000.
# 🤖InventoryAgent
# Produtos considerados de baixo estoque, com base na regra de recomendação (estoque < 10 AND vendas semanais > 15):
#
# - Konbu: Estoque 0, Vendas Semanais 0 (não recomendado, vendas semanais 0)
# - Alice Mutton: Estoque 0, Vendas Semanais 0 (não recomendado, vendas semanais 0)
#
# Nenhum produto atende à condição de baixo estoque com alta demanda para recomendação de reposição.
#
# No entanto, há produtos com estoque baixo (menos que 20) e com algum nível de vendas, que poderiam ser considerados para reposição na análise do AccountingAgent.
#
# Vou preparar um relatório com os produtos que têm estoque baixo (menos ou igual a 20 unidades), listando estoque atual e vendas semanais, para o AccountingAgent avaliar e retornar os itens para comprar dentro do orçamento de R$1000.
# 🤖AccountingAgent
# Com base no inventário e nas vendas semanais, selecionei produtos que estão com estoque baixo (menos ou igual a 20 unidades) e que têm demanda (vendas semanais consideráveis), para consideração de compra dentro do orçamento de R$1000:
#
# Produtos com baixo estoque e vendas significativas:
# - Chang: Estoque 15, Vendas Semanais 5
# - Aniseed Syrup: Estoque 13, Vendas Semanais 32
# - Chef Anton's Cajun Seasoning: Estoque 15, Vendas Semanais 41
# - Northwoods Cranberry Sauce: Estoque 20, Vendas Semanais 10
# - Queso Cabrales: Estoque 22 (um pouco maior que 20 mas com alta venda), Vendas Semanais 91
# - Sir Rodney's Marmalade: Estoque 40 (altamente estocado mas vendas muito baixas)
# - Konbu: Estoque 0, Vendas Semanais 0 (sem demanda, não recomendo compra)
# - Alice Mutton: Estoque 0, Vendas Semanais 0 (sem demanda, não recomendo compra)
#
# Para otimizar a compra dentro do orçamento, focarei nos itens com mais alta demanda e baixo estoque (Chang, Aniseed Syrup, Chef Anton's Cajun Seasoning, Northwoods Cranberry Sauce) evitando produtos com vendas zero e excesso de estoque.
#
# Vou buscar informações de preços de tais produtos e preparar a lista para compra considerando o orçamento disponível. Vou procurar no catálogo de preços e montar a lista para compra.
# 🤖AccountingAgent
# Com base no inventário e nas vendas semanais, selecionei produtos que estão com estoque baixo (menos ou igual a 20 unidades) e que têm demanda (vendas semanais consideráveis), para consideração de compra dentro do orçamento de R$1000:
#
# Produtos com baixo estoque e vendas significativas:
# - Chang: Estoque 15, Vendas Semanais 5
# - Aniseed Syrup: Estoque 13, Vendas Semanais 32
# - Chef Anton's Cajun Seasoning: Estoque 15, Vendas Semanais 41
# - Northwoods Cranberry Sauce: Estoque 20, Vendas Semanais 10
# - Queso Cabrales: Estoque 22 (um pouco maior que 20 mas com alta venda), Vendas Semanais 91
# - Sir Rodney's Marmalade: Estoque 40 (altamente estocado mas vendas muito baixas)
# - Konbu: Estoque 0, Vendas Semanais 0 (sem demanda, não recomendo compra)
# - Alice Mutton: Estoque 0, Vendas Semanais 0 (sem demanda, não recomendo compra)
#
# Para otimizar a compra dentro do orçamento, focarei nos itens com mais alta demanda e baixo estoque (Chang, Aniseed Syrup, Chef Anton's Cajun Seasoning, Northwoods Cranberry Sauce) evitando produtos com vendas zero e excesso de estoque.
#
# Vou buscar informações de preços de tais produtos e preparar a lista para compra considerando o orçamento disponível. Vou procurar no catálogo de preços e montar a lista para compra.
# 🤖AccountingAgent
# Com base no inventário e nas vendas semanais, selecionei produtos que estão com estoque baixo (menos ou igual a 20 unidades) e que têm demanda (vendas semanais consideráveis), para consideração de compra dentro do orçamento de R$1000:
#
# Produtos com baixo estoque e vendas significativas:
# - Chang: Estoque 15, Vendas Semanais 5
# - Aniseed Syrup: Estoque 13, Vendas Semanais 32
# - Chef Anton's Cajun Seasoning: Estoque 15, Vendas Semanais 41
# - Northwoods Cranberry Sauce: Estoque 20, Vendas Semanais 10
# - Queso Cabrales: Estoque 22 (um pouco maior que 20 mas com alta venda), Vendas Semanais 91
# - Sir Rodney's Marmalade: Estoque 40 (altamente estocado mas vendas muito baixas)
# - Konbu: Estoque 0, Vendas Semanais 0 (sem demanda, não recomendo compra)
# - Alice Mutton: Estoque 0, Vendas Semanais 0 (sem demanda, não recomendo compra)
#
# Para otimizar a compra dentro do orçamento, focarei nos itens com mais alta demanda e baixo estoque (Chang, Aniseed Syrup, Chef Anton's Cajun Seasoning, Northwoods Cranberry Sauce) evitando produtos com vendas zero e excesso de estoque.
#
# Vou buscar informações de preços de tais produtos e preparar a lista para compra considerando o orçamento disponível. Vou procurar no catálogo de preços e montar a lista para compra.Baseado no inventário e nas vendas semanais, selecionei os seguintes produtos com estoque baixo para considerar compra dentro do orçamento de R$1000:
#
# 1. Aniseed Syrup
#    - Estoque atual: 13
#    - Vendas semanais: 32
#    - Preço unitário: R$10,00
#    - Reorder Level: 15
#
# 2. Chef Anton's Cajun Seasoning
#    - Estoque atual: 15
#    - Vendas semanais: 41
#    - Preço unitário: R$22,00
#    - Reorder Level: 10
#
# 3. Chang (descontinuado, mas estoque baixo)
#    - Estoque atual: 15
#    - Vendas semanais: 5
#    - Preço unitário: R$19,00
#    - Reorder Level: 20
#
# 4. Northwoods Cranberry Sauce
#    - Estoque atual: 20
#    - Vendas semanais: 10
#    - Preço unitário: R$40,00
#    - Reorder Level: 10
#
# Vou sugerir compras focando em repor até o reorder level para os itens abaixo do nível, priorizando alta demanda e respeitando o orçamento de R$1000.
#
# Vou calcular quantidades e enviar lista para compra.
# Sugestão de compra para repor estoque até o Reorder Level, com orçamento limitado a R$1000:
#
# - Aniseed Syrup: Estoque 13, Reorder Level 15, falta 2 unidades
#   - Preço unitário: R$10,00
#   - Total: R$20,00
#
# - Chef Anton's Cajun Seasoning: Estoque 15, Reorder Level 10, não precisa repor (já acima do Reorder Level)
#
# - Chang: Estoque 15, Reorder Level 20, falta 5 unidades
#   - Preço unitário: R$19,00
#   - Total: R$95,00
#
# - Northwoods Cranberry Sauce: Estoque 20, Reorder Level 10, não precisa repor (já acima do Reorder Level)
#
# Total estimado para compra: R$115,00
#
# Vou encaminhar a lista com 2 unidades de Aniseed Syrup e 5 unidades de Chang para o InventoryPurchasingAgent e atualizar estoque.
# 🤖AccountingAgent
# Com base no inventário e nas vendas semanais, selecionei produtos que estão com estoque baixo (menos ou igual a 20 unidades) e que têm demanda (vendas semanais consideráveis), para consideração de compra dentro do orçamento de R$1000:
#
# Produtos com baixo estoque e vendas significativas:
# - Chang: Estoque 15, Vendas Semanais 5
# - Aniseed Syrup: Estoque 13, Vendas Semanais 32
# - Chef Anton's Cajun Seasoning: Estoque 15, Vendas Semanais 41
# - Northwoods Cranberry Sauce: Estoque 20, Vendas Semanais 10
# - Queso Cabrales: Estoque 22 (um pouco maior que 20 mas com alta venda), Vendas Semanais 91
# - Sir Rodney's Marmalade: Estoque 40 (altamente estocado mas vendas muito baixas)
# - Konbu: Estoque 0, Vendas Semanais 0 (sem demanda, não recomendo compra)
# - Alice Mutton: Estoque 0, Vendas Semanais 0 (sem demanda, não recomendo compra)
#
# Para otimizar a compra dentro do orçamento, focarei nos itens com mais alta demanda e baixo estoque (Chang, Aniseed Syrup, Chef Anton's Cajun Seasoning, Northwoods Cranberry Sauce) evitando produtos com vendas zero e excesso de estoque.
#
# Vou buscar informações de preços de tais produtos e preparar a lista para compra considerando o orçamento disponível. Vou procurar no catálogo de preços e montar a lista para compra.Baseado no inventário e nas vendas semanais, selecionei os seguintes produtos com estoque baixo para considerar compra dentro do orçamento de R$1000:
#
# 1. Aniseed Syrup
#    - Estoque atual: 13
#    - Vendas semanais: 32
#    - Preço unitário: R$10,00
#    - Reorder Level: 15
#
# 2. Chef Anton's Cajun Seasoning
#    - Estoque atual: 15
#    - Vendas semanais: 41
#    - Preço unitário: R$22,00
#    - Reorder Level: 10
#
# 3. Chang (descontinuado, mas estoque baixo)
#    - Estoque atual: 15
#    - Vendas semanais: 5
#    - Preço unitário: R$19,00
#    - Reorder Level: 20
#
# 4. Northwoods Cranberry Sauce
#    - Estoque atual: 20
#    - Vendas semanais: 10
#    - Preço unitário: R$40,00
#    - Reorder Level: 10
#
# Vou sugerir compras focando em repor até o reorder level para os itens abaixo do nível, priorizando alta demanda e respeitando o orçamento de R$1000.
#
# Vou calcular quantidades e enviar lista para compra.
# Sugestão de compra para repor estoque até o Reorder Level, com orçamento limitado a R$1000:
#
# - Aniseed Syrup: Estoque 13, Reorder Level 15, falta 2 unidades
#   - Preço unitário: R$10,00
#   - Total: R$20,00
#
# - Chef Anton's Cajun Seasoning: Estoque 15, Reorder Level 10, não precisa repor (já acima do Reorder Level)
#
# - Chang: Estoque 15, Reorder Level 20, falta 5 unidades
#   - Preço unitário: R$19,00
#   - Total: R$95,00
#
# - Northwoods Cranberry Sauce: Estoque 20, Reorder Level 10, não precisa repor (já acima do Reorder Level)
#
# Total estimado para compra: R$115,00
#
# Vou encaminhar a lista com 2 unidades de Aniseed Syrup e 5 unidades de Chang para o InventoryPurchasingAgent e atualizar estoque.
# 🤖InventoryPurchasingAgent
# O estoque foi atualizado conforme a sugestão do agente de contabilidade e compra:
#
# - Aniseed Syrup: estoque antes 13, estoque atualizado para 15 unidades.
# - Chang: estoque antes 15, estoque atualizado para 20 unidades.
#
# Estes níveis refletem a reposição até o nível de reorder para esses produtos com baixo estoque e demanda relevante.
#
# Se precisar de mais alguma ação, estou à disposição!
# 🤖InventoryPurchasingAgent
# O estoque foi atualizado conforme a sugestão do agente de contabilidade e compra:
#
# - Aniseed Syrup: estoque antes 13, estoque atualizado para 15 unidades.
# - Chang: estoque antes 15, estoque atualizado para 20 unidades.
#
# Estes níveis refletem a reposição até o nível de reorder para esses produtos com baixo estoque e demanda relevante.
#
# Se precisar de mais alguma ação, estou à disposição!
# 🤖InventoryAgent
# Relatório de Reposição de Estoque para o AccountingAgent:
#
# Produtos com baixo estoque previamente:
# - Aniseed Syrup: 13 unidades
# - Chang: 15 unidades
#
# Após recomendação e compra dentro do orçamento de R$1000, os estoques foram atualizados para:
# - Aniseed Syrup: 15 unidades (repôs 2 unidades)
# - Chang: 20 unidades (repôs 5 unidades)
#
# Outros produtos com estoque baixo foram avaliados, mas não incluídos na compra devido à demanda baixa ou produtos descontinuados.
#
# Caso precise de mais análises ou relatório, estou à disposição.
# 🤖InventoryAgent
# Relatório de Reposição de Estoque para o AccountingAgent:
#
# Produtos com baixo estoque previamente:
# - Aniseed Syrup: 13 unidades
# - Chang: 15 unidades
#
# Após recomendação e compra dentro do orçamento de R$1000, os estoques foram atualizados para:
# - Aniseed Syrup: 15 unidades (repôs 2 unidades)
# - Chang: 20 unidades (repôs 5 unidades)
#
# Outros produtos com estoque baixo foram avaliados, mas não incluídos na compra devido à demanda baixa ou produtos descontinuados.
#
# Caso precise de mais análises ou relatório, estou à disposição.
# 🤖AccountingAgent
# O inventário foi analisado e os produtos com estoque baixo e alta demanda foram selecionados para compra dentro do orçamento de R$1000.
#
# Foram comprados:
# - 2 unidades de Aniseed Syrup (de 13 para 15 unidades)
# - 5 unidades de Chang (de 15 para 20 unidades)
#
# O estoque foi atualizado com essas compras, e os níveis antes e depois foram reportados.
#
# Se desejar mais alguma ação ou relatório, por favor, me informe.
# ***** Resultado *****
# O inventário foi analisado e os produtos com estoque baixo e alta demanda foram selecionados para compra dentro do orçamento de R$1000.
#
# Foram comprados:
# - 2 unidades de Aniseed Syrup (de 13 para 15 unidades)
# - 5 unidades de Chang (de 15 para 20 unidades)
#
# O estoque foi atualizado com essas compras, e os níveis antes e depois foram reportados.
#
# Se desejar mais alguma ação ou relatório, por favor, me informe.
# 🤖AccountingAgent
# O inventário foi analisado e os produtos com estoque baixo e alta demanda foram selecionados para compra dentro do orçamento de R$1000.
#
# Foram comprados:
# - 2 unidades de Aniseed Syrup (de 13 para 15 unidades)
# - 5 unidades de Chang (de 15 para 20 unidades)
#
# O estoque foi atualizado com essas compras, e os níveis antes e depois foram reportados.
#
# Se desejar mais alguma ação ou relatório, por favor, me informe.
# ***** Resultado *****
# O inventário foi analisado e os produtos com estoque baixo e alta demanda foram selecionados para compra dentro do orçamento de R$1000.
#
# Foram comprados:
# - 2 unidades de Aniseed Syrup (de 13 para 15 unidades)
# - 5 unidades de Chang (de 15 para 20 unidades)
#
# O estoque foi atualizado com essas compras, e os níveis antes e depois foram reportados.
#
# Se desejar mais alguma ação ou relatório, por favor, me informe.
